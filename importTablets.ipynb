# %%
import csv, re, requests
from urllib import parse

# %%
# read the data from local file
file = "data/tablets.csv"
with open(file, 'r', encoding='utf-8') as data:
    reader = csv.reader(data)
    datalist = list(reader)

# %%
for row in datalist[1:]:
    images = row[20].split(" ")
    temp_tab,_ = Tablet.objects.get_or_create(text_reference=row[0], title=row[0])
    temp_tab.save()
    temp_reg,_ = Region.objects.get_or_create(name=row[2])
    temp_reg.save()
    temp_arch,_ = Archive.objects.get_or_create(name=row[3])
    temp_arch.save()
    temp_dos,_ = Dossier.objects.get_or_create(name=row[4])
    temp_dos.save()
    temp_place,_ = Place.objects.get_or_create(name=row[8])
    temp_place.save()
    print(temp_place.name)
    temp_scribe,_ = Scribe.objects.get_or_create(name=row[10])
    temp_scribe.save()
    temp_period,_ = Period.objects.get_or_create(name=row[11])
    temp_period.save()
    temp_tt,_ = TextType.objects.get_or_create(name=row[16])
    temp_tt.save()
    for x in images:
        temp_img,_ = TabletImage.objects.get_or_create(tablet=temp_tab,image="tablet_img/{}".format(parse.unquote(x)))
        temp_img.save()
    temp_tab.region = temp_reg
    temp_tab.archive = temp_arch
    temp_tab.dossier = temp_dos
    temp_tab.nabucco_no = row[6]
    temp_tab.museum_no = row[7]
    temp_tab.place = temp_place
    temp_tab.cdli_no = row[5]
    temp_tab.place_information = row[9]
    temp_tab.scribe = temp_scribe
    temp_tab.period = temp_period
    if row[12] == "":
        pass
    else:
        temp_tab.date_not_after = row[12]
    if row[13] == "":
        pass
    else:
        temp_tab.date_not_before = row[13]
    temp_tab.babyloneian_time = row[14]
    temp_tab.ductus = row[15]
    temp_tab.text_type = temp_tt
    temp_tab.content = row[17]
    temp_tab.bibliography = re.sub("|", "", row[19])    
    try:
        temp_tab.save()
        #print("Good: ",temp_tab)
    except:
        print("Bad: ",temp_tab)
# Out:
# Borsippa
# Good:  BM 94594
# Gadēti
# Good:  YOS 17 286
# Uruk
# Good:  NCBT 524
# Nippur
# Good:  NBC 6125
# Nippur
# Good:  NBC 6126
# Uruk
# Good:  BIN 1 134
# n/a
# Good:  BM 114791
# Babylon
# Good:  AD -95C
#
# Good:  NBC 6230
# Uruk
# Good:  NCBT 0332
# Uruk
# Good:  BRM 2 19
# Uruk
# Good:  GC 1 129
# Babylon
# Good:  YOS 6 52
# Nippur
# Good:  BE 10 82
# Uruk
# Good:  BRM 2 15
# Babylon
# Good:  AD -132B
# Uruk
# Good:  JCS 36 8
# Uruk
# Good:  BRM 2 13
# omitted
# Good:  BE 9 26
# Uruk
# Good:  BRM 2 11
# Nippur
# Good:  NBC 6133
#
# Good:  NBC 6134
# n/a
# Good:  BM 94614
# broken
# Good:  BOR 2 58
# Uruk
# Good:  NCBT 564
# Nippur
# Good:  NBC 6138
#
# Good:  NBC 6240
#
# Good:  BM 50404
# Babylon
# Good:  BM 42383
#
# Good:  BM 79103
# Uruk
# Good:  GC 1 112
# Uruk
# Good:  GC 1 111
# Uruk
# Good:  NCBT 754
# Uruk
# Good:  NCBT 873
#
# Good:  BM 50509
# Uruk
# Good:  YBC 3406
# Uruk
# Good:  YOS 6 64
# Uruk
# Good:  YOS 7 129
# Babylon
# Good:  BCHP 18
# Babylon
# Good:  BCHP 17
# Dūr-Ugumu
# Good:  YOS 21 203
# Uruk
# Good:  YOS 21 204
# Babylon
# Good:  BCHP 14
#
# Good:  YOS 21 206
#
# Good:  BM 42356+
# Babylon
# Good:  BCHP 11
# Kapru-ša-Nāqidāti
# Good:  YOS 21 209
# Uruk
# Good:  NCBT 0085
# broken
# Good:  YOS 19 80
# Nippur
# Good:  YOS 19 38
#
# Good:  BM 42371
# Borsippa
# Good:  BM 26498
#
# Good:  BM 64240
#
# Good:  NBC 6182
# Bāb-Nār-Šamaš
# Good:  NBC 6199
# Babylon
# Good:  AD -171B
# Uruk
# Good:  NCBT 558
# Uruk
# Good:  YOS 20 24
# n/a
# Good:  YOS 21 210
# Nâru-eššu
# Good:  YOS 21 211
#
# Good:  YOS 21 212
# Bitqa ša Bēl-ētir šīhu ša Bēlet-ša-Uruk
# Good:  YOS 21 213
# Kār-Nanāya šīhu ša Bēltu-ša-Uruk
# Good:  NCBT 535
# Larsa
# Good:  YBC 3527
# Uruk eqlu ša Bēlti ša Uruk ša ina muhhi nāru bitqu
# Good:  YOS 19 76
# Babylon
# Good:  AD -266A
#
# Good:  NBC 6136
#
# Good:  BM 42365
#
# Good:  BM 42364
#
# Good:  BM 42363
# broken
# Good:  NBC 4755 a
# Uruk
# Good:  YBC 4047
#
# Good:  BM 74460
# Nippur
# Good:  BE 9 78
# n/a
# Good:  YOS 21 199
# Uruk
# Good:  YOS 19 279
# n/a
# Good:  YOS 17 300
# Uruk
# Good:  YOS 17 302
#
# Good:  BM 42572
#
# Good:  BM 42571
#
# Good:  BM 74483
# Uruk
# Good:  YBC 3530
# Uruk
# Good:  PTS 2253
#
# Good:  NBC 6169
#
# Good:  BM 74457
# Uruk
# Good:  YOS 17 200
# Nippur
# Good:  YOS 19 61
# Babylon
# Good:  BM 42353
# Uruk
# Good:  YOS 7 49
# Uruk
# Good:  AOAT 358 52
# Kapru
# Good:  YOS 21 201
# Uruk?
# Good:  BRM 1 23
# Uruk
# Good:  YOS 19 098
#
# Good:  BM 42567
#
# Good:  BM 42563
# Uruk
# Good:  NCBT 0211
# n/a
# Good:  BM 82613
#
# Good:  NBC 6172
#
# Good:  NBC 6173
# Nippur
# Good:  BE 10 9
# Āl-Šamaš
# Good:  NBC 6175
# Uruk?
# Good:  BRM 1 15
# Uruk
# Good:  NCBT 540
# n/a
# Good:  BM 78171
# Uruk?
# Good:  BRM 1 12
# Uruk
# Good:  YBC 11476
# Uruk
# Good:  YOS 21 200
# Uruk
# Good:  YBC 3504
# (Babylon)
# Good:  BM 87228
# Bīt-Qatinnu
# Good:  NBC 4718
#
# Good:  BM 42340
# n/a
# Good:  YOS 21 202
# n/a
# Good:  BM 42412
#
# Good:  BM 42556
#
# Good:  BM 42555
# Uruk?
# Good:  BRM 1 13
# Bīt-Šamil
# Good:  YOS 21 205
# Borsippa
# Good:  BM 25625
# Uruk
# Good:  YBC 11390
# Uruk
# Good:  YBC 17067
# Uruk
# Good:  YBC 3508
# Uruk
# Good:  YOS 7 157
# Uruk
# Good:  NCBT 1093
# n/a
# Good:  YOS 21 208
# Uruk
# Good:  GC 1 098
# Borsippa
# Good:  BM 102308
# Bīt šar Bābili
# Good:  YOS 6 100
# Borsippa
# Good:  BM 26569
# n/a
# Good:  NBC 6116
#
# Good:  NBC 6188
# Uruk
# Good:  YOS 20 37
# Ālu-ša-Mušēzib-Nabû
# Good:  YOS 19 44
#
# Good:  BM 42336
# Nippur
# Good:  NBC 6118
# Borsippa
# Good:  BM 27849
#
# Good:  BM 42332
# Uruk
# Good:  YOS 7 28
# Nippur
# Good:  BE 9 49
# Uruk
# Good:  JCS 36 7
# Uruk?
# Good:  BRM 1 19
# Uruk
# Good:  JCS 36 4
# Babylon
# Good:  NBC 4513
# Uruk
# Good:  NBC 4836
#
# Good:  NBC 6208
# Nippur
# Good:  YBC 9232
#
# Good:  BM 49373
# Uruk?
# Good:  BRM 1 10
# Bitqa ša Bēl-ētir šīhu ša Bēlet-ša-Uruk
# Good:  YOS 17 293
#
# Good:  NBC 6190
# omitted
# Good:  NBC 6191
# broken
# Good:  NBC 6227
# Nippur
# Good:  NBC 6195
# Babylon
# Good:  AD -328
# Bitqa ša Bēl-ētir šīhu ša Bēlet-ša-Uruk
# Good:  YOS 17 295
# Nippur
# Good:  YOS 19 36
# Uruk?
# Good:  BRM 1 11
# Ālu-ša-ikkarāti
# Good:  YOS 19 34
# Babylon
# Good:  AD -273B
# Uruk
# Good:  BIN 2 114
# Nippur
# Good:  BE 10 19
# Raqqana
# Good:  BM 64167
# Bīt-Qatinnu
# Good:  NBC 4650
#
# Good:  BM 79364
# Nippur
# Good:  BE 10 14
# Addiāya
# Good:  BE 9 36
# Borsippa
# Good:  BM 17691
# Uruk
# Good:  NCBT 217
# Uruk
# Good:  NBC 4848
# Uruk
# Good:  GC 2 367
# Borsippa
# Good:  BM 102322
# Uruk
# Good:  YOS 6 171
# Uruk
# Good:  NBC 4905
#
# Good:  YOS 21 216
# n/a
# Good:  BM 42424
# Babylon
# Good:  AD -155A
# n/a
# Good:  CTMMA IV 148B
# Šarrānu
# Good:  YOS 19 28
# n/a
# Good:  YOS 21 214
# Borsippa
# Good:  BM 94556
#
# Good:  BM 42369
#
# Good:  YOS 19 23
# omitted
# Good:  BM 49469
# n/a
# Good:  YOS 21 217
# Uruk
# Good:  YOS 20 60
#
# Good:  Camb. 13
# n/a
# Good:  YOS 21 219
# Babylon
# Good:  CT 49 159
# Bīt-Ṣilla
# Good:  BM 74626
# Uruk
# Good:  YOS 7 110
# Babylon
# Good:  AD -226A
# Borsippa
# Good:  BM 82695
# n/a
# Good:  YOS 9 82
# Babylon
# Good:  BM 33984
#
# Good:  BM 42415
# Ālu-ša-ardāni
# Good:  YOS 19 19
# broken
# Good:  YOS 19 18
# Babylon
# Good:  YOS 19 17
# Nippur
# Good:  YOS 19 16
# Borsippa
# Good:  BM 24480
# Āl-Adad
# Good:  NBC 8379
# Nippur
# Good:  BE 10 26
# Uruk
# Good:  YBC 11566
# Nippur
# Good:  EE 106
# Babylon
# Good:  AD -330A+B
# Uruk
# Good:  YOS 6 159
# Babylon
# Good:  BCHP 6
# Nippur
# Good:  EE 3
#
# Good:  BM 42408
# Babylon
# Good:  AD -140C
# Borsippa
# Good:  BM 102024
# Bīt Šama’il
# Good:  GCBC 555
# Nippur
# Good:  BE 9 61
# Borsippa
# Good:  BM 29419
# Babylon
# Good:  BCHP 5
# Til-gubbi
# Good:  BM 42400
# Babylon
# Good:  AD -162
# Nippur
# Good:  NBC 4761
# Babylon
# Good:  AD -168A
# Babylon
# Good:  AD -183A
# Uruk
# Good:  NCBT 460
# Borsippa
# Good:  BM 94638
# Gadēti
# Good:  YOS 7 196
# Borsippa
# Good:  BM 102033
# Uruk?
# Good:  BRM 1 8
# Uruk?
# Good:  BRM 1 7
# Uruk?
# Good:  BRM 1 6
# Uruk?
# Good:  BRM 1 5
# Uruk?
# Good:  BRM 1 4
# Uruk?
# Good:  BRM 1 3
# Uruk?
# Good:  BRM 1 2
# Nippur
# Good:  YOS 19 8
# Uruk
# Good:  NCBT 995
# omitted
# Good:  NBC 8398
# Babylon
# Good:  AD -137A
# Uruk
# Good:  YOS 19 1
# Borsippa
# Good:  BM 94738
# Babylon
# Good:  AD -137D
# Babylon
# Good:  AD -362
# Uruk?
# Good:  BRM 1 18
# Borsippa
# Good:  BM 27779
# broken
# Good:  YBC 11655
# Uruk
# Good:  YOS 7 189
# broken
# Good:  YOS 21 196
# Babylon
# Good:  BM 42568
# n/a
# Good:  YOS 21 198
# n/a
# Good:  BM 95037
# n/a
# Good:  BIN 1 174
# Babylon
# Good:  AD -99B
# Babylon
# Good:  AD -144
# Borsippa
# Good:  BM 94836
# Nippur
# Good:  NBC 4782
# Uruk
# Good:  GC 2 133
# Uruk
# Good:  YOS 6 238
# Babylon
# Good:  AD -270B
# Borsippa
# Good:  BM 94728
# Uruk
# Good:  YBC 11649
# Borsippa
# Good:  BM 102313
#
# Good:  BM 42609+
# Nippur
# Good:  BE 9 1
#
# Good:  BM 79041
# Borsippa
# Good:  BM 85225
# Til-gubbi
# Good:  NBC 6170
# Uruk
# Good:  YOS 19 230
#
# Good:  BM 50501
#
# Good:  BM 42436
# Uruk
# Good:  BRM 2 46
# Uruk
# Good:  YBC 7407
# Naṣībāta
# Good:  YOS 7 174
# Uruk
# Good:  BRM 2 40
# Babylon
# Good:  AD -134
# Nippur
# Good:  NBC 4664
# Babylon
# Good:  AD -105A
# Til-gubbi
# Good:  NBC 6194
#
# Good:  YOS 21 207
# Uruk
# Good:  NCBT 0083
# Borsippa
# Good:  BM 102251
#
# Good:  NBC 6178
# Borsippa
# Good:  BM 114742
#
# Good:  BM 42348
# Ālu-ša-Iṣṣūr-ša-Adad
# Good:  YBC 11319
#
# Good:  BM 17310
# Bīt-Abdā’
# Good:  YOS 19 37
# n/a
# Good:  YOS 21 218
#
# Good:  BM 50548
#
# Good:  BM 42368+
# Babylon
# Good:  AD -204C
# n/a
# Good:  BIN 1 159
# Uruk
# Good:  GC 1 52
# Babylon
# Good:  AD -366A
# Uruk?
# Good:  BRM 1 9
# Nippur
# Good:  NBC 4717
# omitted
# Good:  BM 51523
# Babylon
# Good:  AD -261B
# Til-gubbi
# Good:  NBC 6211
# Til-gubbi
# Good:  NBC 6212
# Uruk
# Good:  NCBT 368
# n/a
# Good:  YOS 21 197
# Ṣīdānu
# Good:  YOS 19 32
# Uruk?
# Good:  BRM 1 21
# Uruk?
# Good:  BRM 1 20
#
# Good:  BM 42362+
# Uruk
# Good:  NBC 4503
# Nippur
# Good:  BE 10 95
#
# Good:  NBC 6228
# Uruk
# Good:  NCBT 511
# Uruk
# Good:  JCS 36 15
# n/a
# Good:  YOS 19 252
# Nippur
# Good:  NBC 6114
# Babylon
# Good:  YBC 3765
# Uruk
# Good:  YOS 7 154
# Uruk
# Good:  YOS 19 256
# Larsa
# Good:  NCBT 519
#
# Good:  BM 50609
# Babylon
# Good:  AD -96A
# Nippur
# Good:  NBC 4781
# Uruk?
# Good:  BRM 1 17
# Uruk?
# Good:  BRM 1 16
# Uruk
# Good:  YNER 1 7
# Uruk?
# Good:  BRM 1 14
# Larsa
# Good:  YNER 1 5
#
# Good:  BM 42299
# Nippur
# Good:  NBC 6229
# Uruk
# Good:  YNER 1 2
# Uruk
# Good:  YNER 1 1
# Bāb Asurrītu
# Good:  YOS 17 290
# Uruk
# Good:  YOS 7 102
# Uruk
# Good:  YOS 7 92
# (Uruk?)
# Good:  NCBT 234
# (Uruk)
# Good:  YBC 9196
# (Uruk)
# Good:  YBC 9285
# (Uruk)
# Good:  YOS 17 203
# (Uruk)
# Good:  YBC 9297
# Uruk
# Good:  YBC 9304
# (Uruk)
# Good:  YOS 17 306
# (Borsippa)
# Good:  YBC 9339
# (Uruk)
# Good:  YOS 17 232
# (Uruk)
# Good:  YBC 9341
#
# Good:  BM 26176
#
# Good:  BM 82808
# Til-Agurrēti (šīhu ša Bēltu-ša-Uruk)
# Good:  YBC 9448
#
# Good:  BM 114803
# (Borsippa)
# Good:  YOS 17 273
# Uruk
# Good:  YOS 6 155
# Borsippa
# Good:  BM 17699
#
# Good:  BM 114801
#
# Good:  BM 114746
#
# Good:  BM 49950
# Sippar
# Good:  BM 114781
# (Babylon)
# Good:  BM 17304
# Borsippa
# Good:  CT 44 81
# (Babylon)
# Good:  BM 78978
# (Babylon)
# Good:  BM 95512
# (Babylon)
# Good:  BM 95597
# Babylon
# Good:  BM 87240
# (Babylon)
# Good:  BM 87249
# (Babylon)
# Good:  BM 87250
# (Babylon)
# Good:  BM 87285
# (Uruk)
# Good:  YBC 9471
# (Uruk)
# Good:  YBC 9472
# (Uruk)
# Good:  YOS 17 210
# Babylon
# Good:  BM 87266
# (Babylon)
# Good:  BM 78425
# (Babylon)
# Good:  CT 44 79

# %%
temp_tab.text_type
# Out:
# <TextType: Receipt>

# %%
#for x in Tablet.objects.all():
    #x.delete()
